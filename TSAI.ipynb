# %%
# !pip install tsai
# Out:
# Requirement already satisfied: tsai in /opt/anaconda3/lib/python3.12/site-packages (0.3.9)
# Requirement already satisfied: fastai>=2.7.14 in /opt/anaconda3/lib/python3.12/site-packages (from tsai) (2.7.18)
# Requirement already satisfied: pyts>=0.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from tsai) (0.13.0)
# Requirement already satisfied: imbalanced-learn>=0.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from tsai) (0.12.3)
# Requirement already satisfied: psutil>=5.4.8 in /opt/anaconda3/lib/python3.12/site-packages (from tsai) (5.9.0)
# Requirement already satisfied: scikit-learn>=1.2 in /opt/anaconda3/lib/python3.12/site-packages (from tsai) (1.5.1)
# Requirement already satisfied: torch<2.3,>=1.10 in /opt/anaconda3/lib/python3.12/site-packages (from tsai) (2.2.1)
# Requirement already satisfied: pip in /opt/anaconda3/lib/python3.12/site-packages (from fastai>=2.7.14->tsai) (24.2)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from fastai>=2.7.14->tsai) (24.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /opt/anaconda3/lib/python3.12/site-packages (from fastai>=2.7.14->tsai) (0.0.7)
# Requirement already satisfied: fastcore<1.8,>=1.5.29 in /opt/anaconda3/lib/python3.12/site-packages (from fastai>=2.7.14->tsai) (1.7.28)
# Requirement already satisfied: torchvision>=0.11 in /opt/anaconda3/lib/python3.12/site-packages (from fastai>=2.7.14->tsai) (0.17.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (from fastai>=2.7.14->tsai) (3.9.2)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (from fastai>=2.7.14->tsai) (2.2.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from fastai>=2.7.14->tsai) (2.32.3)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.12/site-packages (from fastai>=2.7.14->tsai) (6.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /opt/anaconda3/lib/python3.12/site-packages (from fastai>=2.7.14->tsai) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from fastai>=2.7.14->tsai) (10.4.0)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (from fastai>=2.7.14->tsai) (1.13.1)
# Requirement already satisfied: spacy<4 in /opt/anaconda3/lib/python3.12/site-packages (from fastai>=2.7.14->tsai) (3.7.5)
# Requirement already satisfied: numpy>=1.17.3 in /opt/anaconda3/lib/python3.12/site-packages (from imbalanced-learn>=0.11.0->tsai) (1.26.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from imbalanced-learn>=0.11.0->tsai) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from imbalanced-learn>=0.11.0->tsai) (3.5.0)
# Requirement already satisfied: numba>=0.55.2 in /opt/anaconda3/lib/python3.12/site-packages (from pyts>=0.12.0->tsai) (0.60.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from torch<2.3,>=1.10->tsai) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from torch<2.3,>=1.10->tsai) (4.11.0)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.12/site-packages (from torch<2.3,>=1.10->tsai) (1.13.1)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch<2.3,>=1.10->tsai) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch<2.3,>=1.10->tsai) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.12/site-packages (from torch<2.3,>=1.10->tsai) (2024.6.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/anaconda3/lib/python3.12/site-packages (from numba>=0.55.2->pyts>=0.12.0->tsai) (0.43.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai>=2.7.14->tsai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai>=2.7.14->tsai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai>=2.7.14->tsai) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai>=2.7.14->tsai) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai>=2.7.14->tsai) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /opt/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai>=2.7.14->tsai) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai>=2.7.14->tsai) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai>=2.7.14->tsai) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai>=2.7.14->tsai) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai>=2.7.14->tsai) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai>=2.7.14->tsai) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai>=2.7.14->tsai) (4.66.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai>=2.7.14->tsai) (2.8.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai>=2.7.14->tsai) (75.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai>=2.7.14->tsai) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->fastai>=2.7.14->tsai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->fastai>=2.7.14->tsai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->fastai>=2.7.14->tsai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->fastai>=2.7.14->tsai) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch<2.3,>=1.10->tsai) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->fastai>=2.7.14->tsai) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->fastai>=2.7.14->tsai) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->fastai>=2.7.14->tsai) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->fastai>=2.7.14->tsai) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->fastai>=2.7.14->tsai) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->fastai>=2.7.14->tsai) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->fastai>=2.7.14->tsai) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->fastai>=2.7.14->tsai) (2023.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy->torch<2.3,>=1.10->tsai) (1.3.0)
# Requirement already satisfied: language-data>=1.2 in /opt/anaconda3/lib/python3.12/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4->fastai>=2.7.14->tsai) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai>=2.7.14->tsai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai>=2.7.14->tsai) (2.20.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->fastai>=2.7.14->tsai) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/anaconda3/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai>=2.7.14->tsai) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai>=2.7.14->tsai) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.7.14->tsai) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai>=2.7.14->tsai) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai>=2.7.14->tsai) (5.2.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4->fastai>=2.7.14->tsai) (1.2.1)

# %%
from tsai.data.external import get_UCR_data

# Download and load the ArrowHead dataset
X, y, splits = get_UCR_data("ArrowHead", split_data=True)
print(X.shape, y.shape)  # (Samples, Timesteps, Features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 from tsai.data.external import get_UCR_data
#       2 # Download and load the ArrowHead dataset
# ----> 3 X, y, splits = get_UCR_data("ArrowHead", split_data=True)
#       4 print(X.shape, y.shape)
#
# ValueError: too many values to unpack (expected 3)

# %%
dsid = "OliveOil"
X_train, y_train, X_valid, y_valid = get_UCR_data(
    dsid, on_disk=True, force_download=True
)
X_on_disk, y_on_disk, splits = get_UCR_data(
    dsid, on_disk=True, return_split=False, force_download=True
)
X_in_memory, y_in_memory, splits = get_UCR_data(
    dsid, on_disk=False, return_split=False, force_download=True
)
y_tensor = cat2int(y_on_disk)
y_array = y_tensor.numpy()

# %%
import tsai.basics as ts

dsid = "NATOPS"
bs = 16
X, y, splits = ts.get_UCR_data(dsid, return_split=False)
tfms = [None, [TSCategorize()]]
dsets = ts.TSDatasets(X, y, tfms=tfms, splits=splits)
dls = ts.TSDataLoaders.from_dsets(
    dsets.train, dsets.valid, bs=bs, num_workers=0, shuffle=False
)
model = ts.RNN(
    c_in,
    c_out,
    hidden_size=100,
    n_layers=2,
    bidirectional=True,
    rnn_dropout=0.5,
    fc_dropout=0.5,
)
learn = ts.Learner(dls, model, metrics=accuracy)
ts.learn.fit_one_cycle(1, 3e-3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 9
#       7 dsets = ts.TSDatasets(X, y, tfms=tfms, splits=splits)
#       8 dls   = ts.TSDataLoaders.from_dsets(dsets.train, dsets.valid, bs=bs, num_workers=0, shuffle=False)
# ----> 9 model = ts.RNN(c_in, c_out, hidden_size=100,n_layers=2,bidirectional=True,rnn_dropout=.5,fc_dropout=.5)
#      10 learn = ts.Learner(dls, model,  metrics=accuracy)
#      11 ts.learn.fit_one_cycle(1, 3e-3)
#
# AttributeError: module 'tsai.basics' has no attribute 'RNN'
